# %%
import pandas as pd

# %%
#Importing csv as dataframe
df= pd.read_csv("wine_filtered.csv")
df
# Out:
#         Unnamed: 0      country  \
# 0                0        Italy
# 1                1     Portugal
# 2                2           US
# 3                3           US
# 4                4           US
# 5                5        Spain
# 6                6        Italy
# 7                7       France
# 8                8      Germany
# 9                9       France
# 10              10           US
# 11              11       France
# 12              12           US
# 13              13        Italy
# 14              14           US
# 15              15      Germany
# 16              16    Argentina
# 17              17    Argentina
# 18              18        Spain
# 19              19           US
# 20              20           US
# 21              21           US
# 22              22        Italy
# 23              23           US
# 24              24        Italy
# 25              25           US
# 26              26        Italy
# 27              27        Italy
# ...

# %%
#Number of wines per country
df.pivot_table(index=['country'], aggfunc='size')
# Out:
# country
# Argentina                  3544
# Armenia                       2
# Australia                  2197
# Austria                    3034
# Bosnia and Herzegovina        2
# Brazil                       49
# Bulgaria                    132
# Canada                      226
# Chile                      4184
# China                         1
# Croatia                      70
# Cyprus                       10
# Czech Republic               11
# Egypt                         1
# England                      63
# France                    20353
# Georgia                      76
# Germany                    1992
# Greece                      432
# Hungary                     129
# India                         8
# Israel                      466
# Italy                     17940
# Lebanon                      32
# Luxembourg                    5
# Macedonia                    11
# Mexico                       68
# Moldova                      56
# Morocco                      24
# ...

# %%
#Filtering countries with less than 2 wines
dfindex=df.set_index('country')
dfindex
dff=dfindex.drop(['China', 'Egypt', 'Slovakia'] )
dff.pivot_table(index=['country'], aggfunc='size')
dfg=dff.reset_index()
dfg
# Out:
#             country  Unnamed: 0  \
# 0             Italy           0
# 1          Portugal           1
# 2                US           2
# 3                US           3
# 4                US           4
# 5             Spain           5
# 6             Italy           6
# 7            France           7
# 8           Germany           8
# 9            France           9
# 10               US          10
# 11           France          11
# 12               US          12
# 13            Italy          13
# 14               US          14
# 15          Germany          15
# 16        Argentina          16
# 17        Argentina          17
# 18            Spain          18
# 19               US          19
# 20               US          20
# 21               US          21
# 22            Italy          22
# 23               US          23
# 24            Italy          24
# 25               US          25
# 26            Italy          26
# 27            Italy          27
# ...

# %%
print ('none')
# Out:
# none

# %%
print ('none')
# Out:
# none

# %%
print ('none')
# Out:
# none

# %%
#Box Plot points by Country
import matplotlib.pyplot as plt

import seaborn as sns

plt.figure(figsize=(16,12))

country = df.country.value_counts()[:20] #number of countries 
plt.subplot(2,1,2)
g1 = sns.boxplot(x='country', y='points',data=df[df.country.isin(country.index.values)])
g1.set_title("Points by Country Of Wine Origin", fontsize=20)
g1.set_xlabel("Country's ", fontsize=15)
g1.set_ylabel("Points", fontsize=15)
g1.set_xticklabels(g1.get_xticklabels(),rotation=45)

plt.subplots_adjust(hspace = 0.6,top = 0.9)

plt.show()

# %%
#Number of wines availed by country
import matplotlib.pyplot as plt

import seaborn as sns

plt.figure(figsize=(14,6))

country = df.country.value_counts()[:20]

g = sns.countplot(x='country', data=df[df.country.isin(country.index.values)])
g.set_title("Country Of Wine Origin Count", fontsize=20)
g.set_xlabel("Country's ", fontsize=15)
g.set_ylabel("Count", fontsize=15)
g.set_xticklabels(g.get_xticklabels(),rotation=45)
# Out:
# [Text(0, 0, 'Italy'),
#  Text(0, 0, 'Portugal'),
#  Text(0, 0, 'US'),
#  Text(0, 0, 'Spain'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Germany'),
#  Text(0, 0, 'Argentina'),
#  Text(0, 0, 'Chile'),
#  Text(0, 0, 'Australia'),
#  Text(0, 0, 'Austria'),
#  Text(0, 0, 'South Africa'),
#  Text(0, 0, 'New Zealand'),
#  Text(0, 0, 'Israel'),
#  Text(0, 0, 'Hungary'),
#  Text(0, 0, 'Greece'),
#  Text(0, 0, 'Romania'),
#  Text(0, 0, 'Canada'),
#  Text(0, 0, 'Turkey'),
#  Text(0, 0, 'Uruguay'),
#  Text(0, 0, 'Bulgaria')]

# %%
#Ploting the points ratio per coutry
import matplotlib.pyplot as plt

import seaborn as sns

plt.figure(figsize=(50,20))

country = dfg.country.value_counts()[:49]
plt.subplot(2,1,2)
g1 = sns.boxplot(x='country', y='points',data=dfg[dfg.country.isin(country.index.values)])
g1.set_title("Points by Country Of Wine Origin", fontsize=20)
g1.set_xlabel("Country's ", fontsize=15)
g1.set_ylabel("Points", fontsize=15)
g1.set_xticklabels(g1.get_xticklabels(),rotation=70)

plt.subplots_adjust(hspace = 0.6,top = 0.9)

plt.show()

# %%
#Price by country
import matplotlib.pyplot as plt

import seaborn as sns
plt.figure(figsize=(25,50))

country = df.country.value_counts()[:35]

plt.subplot(5,2,1)
g = sns.barplot(x='price', y='country',
                  data=df.loc[(df.country.isin(country.index.values))])
g.set_title("Price by Country Of Wine Origin", fontsize=20)
g.set_xlabel("Country's ", fontsize=15)
g.set_ylabel("Price Dist(US)", fontsize=15)
g.set_xticklabels(g.get_xticklabels(),rotation=70)
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '')]
